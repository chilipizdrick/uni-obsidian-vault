# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (2.1.1)
# Requirement already satisfied: pandas in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (2.2.3)
# Requirement already satisfied: matplotlib in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (3.9.2)
# Requirement already satisfied: scikit-learn in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (1.5.2)
# Requirement already satisfied: seaborn in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (0.13.2)
# Requirement already satisfied: notebook in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (7.2.2)
# Requirement already satisfied: nbconvert in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (7.16.4)
# Requirement already satisfied: networkx in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 8)) (3.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from pandas->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from pandas->-r requirements.txt (line 2)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from pandas->-r requirements.txt (line 2)) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 3)) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 3)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 3)) (24.1)
# Requirement already satisfied: pillow>=8 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 3)) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 3)) (3.1.4)
# Requirement already satisfied: scipy>=1.6.0 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from scikit-learn->-r requirements.txt (line 4)) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from scikit-learn->-r requirements.txt (line 4)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from scikit-learn->-r requirements.txt (line 4)) (3.5.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from notebook->-r requirements.txt (line 6)) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from notebook->-r requirements.txt (line 6)) (2.27.3)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from notebook->-r requirements.txt (line 6)) (4.2.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from notebook->-r requirements.txt (line 6)) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from notebook->-r requirements.txt (line 6)) (6.4.1)
# Requirement already satisfied: beautifulsoup4 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from nbconvert->-r requirements.txt (line 7)) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from nbconvert->-r requirements.txt (line 7)) (6.1.0)
# Requirement already satisfied: defusedxml in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from nbconvert->-r requirements.txt (line 7)) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from nbconvert->-r requirements.txt (line 7)) (3.1.4)
# Requirement already satisfied: jupyter-core>=4.7 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from nbconvert->-r requirements.txt (line 7)) (5.7.2)
# Requirement already satisfied: jupyterlab-pygments in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from nbconvert->-r requirements.txt (line 7)) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from nbconvert->-r requirements.txt (line 7)) (2.1.5)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from nbconvert->-r requirements.txt (line 7)) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from nbconvert->-r requirements.txt (line 7)) (0.10.0)
# Requirement already satisfied: nbformat>=5.7 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from nbconvert->-r requirements.txt (line 7)) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from nbconvert->-r requirements.txt (line 7)) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from nbconvert->-r requirements.txt (line 7)) (2.18.0)
# Requirement already satisfied: tinycss2 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from nbconvert->-r requirements.txt (line 7)) (1.3.0)
# Requirement already satisfied: traitlets>=5.1 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from nbconvert->-r requirements.txt (line 7)) (5.14.3)
# Requirement already satisfied: six>=1.9.0 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from bleach!=5.0.0->nbconvert->-r requirements.txt (line 7)) (1.16.0)
# Requirement already satisfied: webencodings in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from bleach!=5.0.0->nbconvert->-r requirements.txt (line 7)) (0.5.1)
# Requirement already satisfied: platformdirs>=2.5 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from jupyter-core>=4.7->nbconvert->-r requirements.txt (line 7)) (4.3.6)
# Requirement already satisfied: anyio>=3.1.0 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (4.6.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (23.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (7.4.9)
# Requirement already satisfied: jupyter-events>=0.9.0 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (0.21.0)
# Requirement already satisfied: pyzmq>=24 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (24.0.1)
# Requirement already satisfied: send2trash>=1.8.2 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from jupyterlab<4.3,>=4.2.0->notebook->-r requirements.txt (line 6)) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from jupyterlab<4.3,>=4.2.0->notebook->-r requirements.txt (line 6)) (0.27.2)
# Requirement already satisfied: ipykernel>=6.5.0 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from jupyterlab<4.3,>=4.2.0->notebook->-r requirements.txt (line 6)) (6.29.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from jupyterlab<4.3,>=4.2.0->notebook->-r requirements.txt (line 6)) (2.2.5)
# Requirement already satisfied: setuptools>=40.1.0 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from jupyterlab<4.3,>=4.2.0->notebook->-r requirements.txt (line 6)) (65.5.0)
# Requirement already satisfied: babel>=2.10 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->-r requirements.txt (line 6)) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->-r requirements.txt (line 6)) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->-r requirements.txt (line 6)) (4.23.0)
# Requirement already satisfied: requests>=2.31 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->-r requirements.txt (line 6)) (2.32.3)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from nbformat>=5.7->nbconvert->-r requirements.txt (line 7)) (2.20.0)
# Requirement already satisfied: soupsieve>1.2 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from beautifulsoup4->nbconvert->-r requirements.txt (line 7)) (2.6)
# Requirement already satisfied: idna>=2.8 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (21.2.0)
# Requirement already satisfied: certifi in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->-r requirements.txt (line 6)) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->-r requirements.txt (line 6)) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->-r requirements.txt (line 6)) (0.14.0)
# Requirement already satisfied: comm>=0.1.1 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook->-r requirements.txt (line 6)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook->-r requirements.txt (line 6)) (1.8.6)
# Requirement already satisfied: ipython>=7.23.1 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook->-r requirements.txt (line 6)) (8.27.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook->-r requirements.txt (line 6)) (0.1.7)
# Requirement already satisfied: nest-asyncio in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook->-r requirements.txt (line 6)) (1.6.0)
# Requirement already satisfied: psutil in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook->-r requirements.txt (line 6)) (6.0.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->-r requirements.txt (line 6)) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->-r requirements.txt (line 6)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->-r requirements.txt (line 6)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->-r requirements.txt (line 6)) (0.20.0)
# Requirement already satisfied: entrypoints in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (0.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook->-r requirements.txt (line 6)) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook->-r requirements.txt (line 6)) (2.2.3)
# Requirement already satisfied: ptyprocess in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from terminado>=0.8.3->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (0.7.0)
# Requirement already satisfied: decorator in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook->-r requirements.txt (line 6)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook->-r requirements.txt (line 6)) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook->-r requirements.txt (line 6)) (3.0.48)
# Requirement already satisfied: stack-data in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook->-r requirements.txt (line 6)) (0.6.3)
# Requirement already satisfied: typing-extensions>=4.6 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook->-r requirements.txt (line 6)) (4.12.2)
# Requirement already satisfied: pexpect>4.3 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook->-r requirements.txt (line 6)) (4.9.0)
# Requirement already satisfied: fqdn in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (1.5.1)
# Requirement already satisfied: isoduration in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (3.0.0)
# Requirement already satisfied: uri-template in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (24.8.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (1.17.1)
# Requirement already satisfied: pycparser in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook->-r requirements.txt (line 6)) (0.8.4)
# Requirement already satisfied: wcwidth in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook->-r requirements.txt (line 6)) (0.2.13)
# Requirement already satisfied: arrow>=0.15.0 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: executing>=1.2.0 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook->-r requirements.txt (line 6)) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook->-r requirements.txt (line 6)) (2.4.1)
# Requirement already satisfied: pure-eval in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook->-r requirements.txt (line 6)) (0.2.3)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/alex/Projects/python/jupyter/.venv/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (2.9.0.20241003)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
def z_quality(x, y):
    return (x - 3*y + 1) / (x**2 + y**2 + 1)

def exchange_scheme(old_x, old_y, sorted_id):
    x = [0 for _ in range(4)]
    y = [0 for _ in range(4)]

    x[0] = old_x[sorted_id[1]]
    y[0] = old_y[sorted_id[0]]

    x[1] = old_x[sorted_id[2]]
    y[1] = old_y[sorted_id[0]]

    x[2] = old_x[sorted_id[0]]
    y[2] = old_y[sorted_id[1]]

    x[3] = old_x[sorted_id[0]]
    y[3] = old_y[sorted_id[2]]

    return x, y

def sort_ids(z):
    return sorted(range(len(z)), key=lambda k: z[k])

def evolution_step(x, y, z):
    _, min_id = min((value, id) for (id, value) in enumerate(z))

    x = x[:]
    y = y[:]
    z = z[:]

    x.pop(min_id)
    y.pop(min_id)
    z.pop(min_id)

    return x,y,z

def evolution_steps(x, y, steps_num=4):
    results = []

    for i in range(steps_num):
        arr_z = [z_quality(j, y[i]) for i, j in enumerate(x)]
        x, y, z = evolution_step(x, y, arr_z)
        x, y = exchange_scheme(x, y, sort_ids(z))
        results.append([x, y, sum(arr_z), arr_z])

    return x, y, results

x = [-2, -1, 0, 2]
y = [-2, 0, -1, 1]
final_x, final_y, results = evolution_steps(x, y)

print(final_x)
print(final_y)

for i in range(len(results)): 
    print(f"max_{i+1}_step: {results[i][2]}")

quality_arr_z = []
for i in range(len(results)):
    quality_arr_z += results[i][3]

print(f"max Z: {max(quality_arr_z)}")
# Out:
# [2, 2, -2, -2]
# [1, 1, -1, -2]
# max_1_step: 2.5555555555555554
# max_2_step: 0.3333333333333335
# max_3_step: 0.8888888888888888
# max_4_step: 0.6666666666666667
# max Z: 2.0

# %%
import networkx as nx
from math import e
import matplotlib.pyplot as plt

def probability(delta, T):
    return 100 * e**(-delta / T)

def reduct_temp(T):
    return 0.5 * T

def edge_length(i, j, distances, round_trip=True):
    if round_trip:
        return max((item[2] if (item[0] == 1 and item[1] == j) or (item[1] == i and item[0] == j) else -1 for item in distances))
    else:
        return max((item[2] if item[0] == 1 and item[1] == j else -1 for item in distances))

def route_length(V, distances):
    edges = []
    for i in range(len(V) - 1):
        edges.append(edge_length(V[i], V[i+1], distances))
    return sum(edges)

def route_one_replacement(V, Z, replacement_by_name=True):
    decrement = int(replacement_by_name)
    V[Z[0] - decrement], V[Z[1] - decrement] = V[Z[1] - decrement], V[Z[0] - decrement]
    return V

def route_replacement(V, Z):
    for z in Z:
        V = route_one_replacement(V, z)
    return V

def choose_route(distances, V, Z, T, P):
    sum_length = route_length(V, distances)
    arr_sum = [sum_length]
    for i in range(len(Z)):
        new_V = route_one_replacement(V.copy(), Z[i])
        new_S = route_length(new_V, distances)
        arr_sum.append(new_S)
        delta_S = new_S - sum_length
        if delta_S >= 0:
            p = probability(delta_S, T)
            if p > P[i]:
                V = new_V
                sum_length = new_S
        else:
            V = new_V
            sum_length = new_S
        T = reduct_temp(T)
    return V, arr_sum

def draw_route_graph(distances, best_route):
    new_distances = []
    for i in range(len(best_route) - 1):
        for distance in distances:
            if distance[0] == best_route[i] and distance[1] == best_route[i+1] or distance[1] == best_route[i] and distance[0] == best_route[i+1]:
                new_distances.append(distance)
    graph = nx.Graph()
    graph.add_weighted_edges_from(new_distances)
    nx.draw_kamada_kawai(graph, node_size=2000, with_labels=True)


distances = [
    (1, 2, 18),
    (1, 3, 41),
    (1, 4, 36),
    (1, 5, 29),
    (1, 6, 19),
    (2, 3, 27),
    (2, 4, 31),
    (2, 5, 37),
    (2, 6, 15),
    (3, 4, 19),
    (3, 5, 42),
    (3, 6, 23),
    (4, 5, 24),
    (4, 6, 17),
    (5, 6, 24),
]
V = [1, 3, 4, 5, 6, 2, 1]
Z = [
    (2, 4),
    (3, 4),
    (4, 6),
    (5, 6),
]
P = [63, 49, 45, 53]
T = 100

graph = nx.Graph()
graph.add_weighted_edges_from(distances)
nx.draw_kamada_kawai(graph, node_size=2000, with_labels=True)
plt.show()
best_route, arr_length = choose_route(distances, V, Z, T, P)
draw_route_graph(distances, best_route)
plt.show()
print(f"Best chosen route: {best_route}")
print(f"Best chosen route length: {route_length(best_route, distances)}")
print(f"Lenths of all considered routes: {arr_length}")
# Out:
# Best chosen route: [1, 5, 3, 4, 6, 2, 1]
# Best chosen route length: 162
# Lenths of all considered routes: [161, 161, 162, 189, 176]

# %%
distances = [
    (1, 2, 18),
    (1, 3, 41),
    (1, 4, 36),
    (1, 5, 29),
    (1, 6, 19),
    (2, 3, 27),
    (2, 4, 31),
    (2, 5, 37),
    (2, 6, 15),
    (3, 4, 19),
    (3, 5, 42),
    (3, 6, 23),
    (4, 5, 24),
    (4, 6, 17),
    (5, 6, 24),
]
V = [1, 3, 4, 5, 6, 2, 1]
Z = [
    (3, 4),
]
P = [63]
T = 100

graph = nx.Graph()
graph.add_weighted_edges_from(distances)
nx.draw_kamada_kawai(graph, node_size=2000, with_labels=True)
plt.show()
best_route, arr_length = choose_route(distances, V, Z, T, P)
draw_route_graph(distances, best_route)
plt.show()
print(f"Best chosen route: {best_route}")
print(f"Best chosen route length: {route_length(best_route, distances)}")
print(f"Lenths of all considered routes: {arr_length}")
# Out:
# Best chosen route: [1, 3, 5, 4, 6, 2, 1]
# Best chosen route length: 161
# Lenths of all considered routes: [161, 161]

# %%
distances = [
    (1, 2, 18),
    (1, 3, 41),
    (1, 4, 36),
    (1, 5, 29),
    (1, 6, 19),
    (2, 3, 27),
    (2, 4, 31),
    (2, 5, 37),
    (2, 6, 15),
    (3, 4, 19),
    (3, 5, 42),
    (3, 6, 23),
    (4, 5, 24),
    (4, 6, 17),
    (5, 6, 24),
]
V = [1, 3, 4, 5, 6, 2, 1]
Z = [
    (2, 4),
    (2, 3),
    (3, 4),
    (4, 6),
    (4, 5),
    (5, 6),
]
P = [63, 49, 45, 53, 63, 42]
T = 100

graph = nx.Graph()
graph.add_weighted_edges_from(distances)
nx.draw_kamada_kawai(graph, node_size=2000, with_labels=True)
plt.show()
best_route, arr_length = choose_route(distances, V, Z, T, P)
draw_route_graph(distances, best_route)
plt.show()
print(f"Best chosen route: {best_route}")
print(f"Best chosen route length: {route_length(best_route, distances)}")
print(f"Lenths of all considered routes: {arr_length}")
# Out:
# Best chosen route: [1, 4, 3, 5, 6, 2, 1]
# Best chosen route length: 161
# Lenths of all considered routes: [161, 161, 162, 161, 181, 180, 181]

# %%
distances = [
    (1, 2, 18),
    (1, 3, 41),
    (1, 4, 36),
    (1, 5, 29),
    (1, 6, 19),
    (2, 3, 27),
    (2, 4, 31),
    (2, 5, 37),
    (2, 6, 15),
    (3, 4, 19),
    (3, 5, 42),
    (3, 6, 23),
    (4, 5, 24),
    (4, 6, 17),
    (5, 6, 24),
]
V = [1, 3, 4, 5, 6, 2, 1]
Z = [
    (2, 4),
    (2, 3),
    (4, 5),
]
P = [3, 100, 2]
T = 100

graph = nx.Graph()
graph.add_weighted_edges_from(distances)
nx.draw_kamada_kawai(graph, node_size=2000, with_labels=True)
plt.show()
best_route, arr_length = choose_route(distances, V, Z, T, P)
draw_route_graph(distances, best_route)
plt.show()
print(f"Best chosen route: {best_route}")
print(f"Best chosen route length: {route_length(best_route, distances)}")
print(f"Lenths of all considered routes: {arr_length}")
# Out:
# Best chosen route: [1, 5, 4, 6, 3, 2, 1]
# Best chosen route length: 170
# Lenths of all considered routes: [161, 161, 162, 170]
